# %% [markdown]
# # Тематическая модель [Постнауки](http://postnauka.ru)
# ## Peer Review (optional)

# %% [markdown]
# В этом задании мы применим аппарат тематического моделирования к коллекции текстовых записей видеолекций, скачанных с сайта Постнаука. Мы будем визуализировать модель и создавать прототип тематического навигатора по коллекции. В коллекции 1728 документов, размер словаря - 38467 слов. Слова лемматизированы, то есть приведены к начальной форме, с помощью программы [mystem](https://tech.yandex.ru/mystem/), коллекция сохранена в [формате vowpal wabbit](http://docs.bigartm.org/en/latest/formats.html). В каждой строке до первой черты записана информация о документе (ссылка на страницу с лекцией), после первой черты следует описание документа. Используются две модальности - текстовая ("text") и модальность авторов ("author"); у каждого документа один автор.

# %% [markdown]
# Для выполнения задания понадобится библиотека [BigARTM](http://docs.bigartm.org). В демонстрации показан пример использования библиотеки версии 0.7.4, на сайте предлагается скачивать версию 0.8.0. В новой версии изменены принципы работы со словарями: они вынесены в отдельный класс (пример в [Release Notes](http://docs.bigartm.org/en/stable/release_notes/python.html)). Строить модель и извлекать ее параметры нужно так же, как показано в демонстрации. Вы можете использовать [предыдущий релиз](http://bigartm.readthedocs.io/en/v0.7.6/download.html) или [новый релиз](http://docs.bigartm.org/en/latest/download.html) на ваше усмотрение.
#
# Спецификации всех функций вы можете смотреть на странице [Python API](http://bigartm.readthedocs.io/en/stable/python_interface.html).

# %%
import artm

# %%
from matplotlib import pyplot as plt
import seaborn
# %matplotlib inline
seaborn.set_style("whitegrid", {'axes.grid' : False})

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ##### Считывание данных

# %% [markdown]
# Создайте объект класса artm.BatchVectorizer, который будет ссылаться на директорию с пакетами данных (батчами). Чтобы библиотека могла преобразовать текстовый файл в батчи, создайте пустую директорию и укажите ее название в параметре target_folder. Размер батча для небольших коллекций (как наша) не важен, вы можете указать любой.

# %%
# Ваш код
batch_vectorizer = artm.BatchVectorizer(data_path="lectures.txt", data_format="vowpal_wabbit", target_folder='batch_cache')

# %% [markdown]
# ##### Инициализация модели

# %% [markdown]
# Создайте объект класса artm.Model с 30 темами, именами тем, указанными ниже и единичными весами обеих модальностей. Количество тем выбрано не очень большим, чтобы вам было удобнее работать с темами. На этой коллекции можно строить и большее число тем, тогда они будут более узко специализированы.

# %%
T = 30   # количество тем
topic_names=["sbj"+str(i) for i in range(T-1)]+["bcg"]
# Ваш код
model_artm = artm.ARTM(num_topics=30, topic_names=topic_names, class_ids={"text": 1, "author": 1},
                      num_document_passes=2, reuse_theta=True, cache_theta=True, seed=10)

# %% [markdown]
# Мы будем строить 29 предметных тем и одну фоновую.
#
# Соберите словарь с помощью метода gather_dictionary и инициализируйте модель, указав random_seed=1. Обязательно укажите свое название словаря, оно понадобится при добавлении регуляризаторов.

# %%
# Ваш код
dictionary = artm.Dictionary('dict')
dictionary.gather(batch_vectorizer.data_path)

# %%
model_artm.initialize(dictionary)

# %% [markdown]
# ##### Добавление score

# %% [markdown]
# Создайте два измерителя качества artm.TopTokensScore - по одному для каждой модальности; количество токенов 15. Названия для score придумайте самостоятельно.

# %%
# Ваш код
model_artm.scores.add(artm.TopTokensScore(name='top_words', num_tokens=15, class_id='text'))
model_artm.scores.add(artm.TopTokensScore(name='top_authors', num_tokens=15, class_id='author'))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-14-b13888e190c7> in <module>()
#       1 # Ваш код
# ----> 2 model_artm.scores.add(artm.TopTokensScore(name='top_words', num_tokens=15, class_id='text'))
#       3 model_artm.scores.add(artm.TopTokensScore(name='top_authors', num_tokens=15, class_id='author'))
#
# /home/aleksei/.virtualenvs/python2/local/lib/python2.7/site-packages/artm/scores.pyc in add(self, score, overwrite)
#      52         if name in self._data and not overwrite:
#      53             raise AttributeError("Unable to replace existing score.\
# ---> 54                                   If you really want to do it use overwrite=True argument")
#      55         # next statement represents ternary operator
#      56         register_func = (self._master.create_score if name not in self._data else
#
# AttributeError: Unable to replace existing score.                                  If you really want to do it use overwrite=True argument

# %% [markdown]
# ##### Построение модели

# %% [markdown]
# Мы будем строить модель в два этапа: сначала добавим сглаживающий регуляризатор фоновой темы и настроим параметры модели, затем - добавим разреживающий регуляризатор предметрых тем и выполним еще несколько итераций. Так мы сможем получить наиболее чистые от фоновых слов предметные темы. Сглаживающий и разреживающий регуляризаторы задаются одним и тем же классом artm.SmoothSparsePhiRegularizer: если коэффициент tau положительный, то регуляризатор будет сглаживающий, если отрицательный - разреживающий.
#
# Если вы хотите подробнее разобраться, как выполняется регуляризация тематической модели в BigARTM, вы можете прочитать [статью](https://s3-eu-west-1.amazonaws.com/artm/voron-potap14artm-rus.pdf), раздел 4.

# %% [markdown]
# Добавьте сглаживающий регуляризатор с коэффициентом tau = 1e5, указав название своего словаря в dictionary, модальность текста в class_ids и тему "bcg" в topic_names.

# %%
# Ваш код
model_artm.regularizers.add(artm.SmoothSparsePhiRegularizer(name='smoothScore', 
                                                      tau=1e5, class_ids='text', dictionary=dictionary, 
                                                      topic_names='bcg'))

# %% [markdown]
# Выполните 30 итераций по коллекции (num_collection_passes), количество внутренних итераций установите равным 1. Используйте метод fit_offline модели.

# %%
# Ваш код
model_artm.fit_offline(batch_vectorizer=batch_vectorizer, num_collection_passes=30)

# %% [markdown]
# Добавьте разреживающий регуляризатор с коэффициентом tau=-1e5, указав название своего словаря, модальность текста в class_ids и все темы "sbjX" в topic_names.

# %%
# Ваш код
model_artm.regularizers.add(artm.SmoothSparsePhiRegularizer(name='sparseScore', 
                                                            tau=-1e5, class_ids='text', dictionary=dictionary, 
                                                            topic_names=topic_names[:-1]))

# %% [markdown]
# Выполните еще 15 проходов по коллекции.

# %%
# Ваш код
model_artm.fit_offline(batch_vectorizer=batch_vectorizer, num_collection_passes=15)

# %% [markdown]
# ##### Интерпретация тем

# %% [markdown]
# Используя созданные score, выведите топы слов и топы авторов в темах. Удобнее всего выводить топ слов каждой темы с новой строки, указывая название темы в начале строки, и аналогично с авторами.

# %%
# Ваш код
for topic_name in model_artm.topic_names:
    print topic_name + ': ',
    tokens = model_artm.score_tracker["top_words"].last_tokens
    for word in tokens[topic_name]:    
        print word,
    print
# Out:
# sbj0:  клетка организм белок болезнь заболевание биологический генетический ткань препарат медицина молекулярный вирус бактерия биология молекула
# sbj1:  вселенная излучение эффект темный масштаб распределение стадия реликтовый гигантский космологический мощность параметр метеорит флуктуация землетрясение
# sbj2:  ген геном растение мутация отбор хромосома эволюция эволюционный животное генетика юрист наследственный популяция яйцеклетка участок
# sbj3:  миф мифология смерть обряд шаман екатерина академия мифологический гусейнов тело ритуал суд гасан шаманский императорский
# sbj4:  память задача психология мышление решение восприятие психологический когнитивный трудность психолог интеллект внимание сознание зрительный опыт
# sbj5:  свет расстояние размер телескоп космический спутник спектр измерять наблюдение рентгеновский орбита прибор флуоресцентный небо диапазон
# sbj6:  город бог литература царь литературный греческий искусство городской герой произведение религия эпоха имя религиозный душа
# sbj7:  днк пространство последовательность рнк матрица алгоритм математика линейный песня спираль ошибка машинный цепочка многомерный вычислительный
# sbj8:  политический государство власть исторический империя политика римский король церковь правитель император средневековый народ свобода правовой
# sbj9:  текст словарь русь перевод святой музей анекдот андрей поэзия устный князь апостол стих филологический фольклор
# sbj10:  театр костюм пьеса актер роман гумбольдт театральный художник мода локальный зритель женский сцена салон бахтин
# sbj11:  право оптический лазерный сага собственность владение собственник имущество критерий договор требование импульс суд кодекс снорри
# sbj12:  культура социальный наука философия общество рассказывать понятие знание социология культурный философский кандидат философ книга научный
# sbj13:  территория город северный раса население южный африка регион местный остров америка предок север майя памятник
# sbj14:  материал структура химический соединение молекула вещество свойство химия метод углерод применение давление поверхность полимер атом
# sbj15:  платон парадокс генеалогия относительность мышца поляризация отсчет шахматы кремний дрожжи амилоидный союзный стержень агрегат амилоид
# sbj16:  ребенок женщина семья мужчина сон мать взрослый родитель медиа стратегия детство гендерный кодирование мужской материнство
# sbj17:  вода китай микроорганизм океан море китайский озеро метан климат микроб азия глубина экосистема эра бассейн
# sbj18:  фильм кино кинематограф культовый самка самец солнечный лосев игрушка энергетика электричество топливо вестерн еврей снимать
# sbj19:  компьютер данные сеть робот информация технология программа компания компьютерный пользователь должник интернет вычисление разработка обязательство
# sbj20:  университет образование профессор факультет экономический кафедра преподавание диссертация орден катастрофа ярослав курс профессия университетский компетенция
# sbj21:  галактика черный дыра газ скопление звездный гравитационный спиральный миллиард диск линзовидный всплеск вращение вращаться звездообразование
# sbj22:  лицо экономика конфликт эмоция идентичность коллективный праздник категория принятие ценность международный экономист мотивация травма преступление
# sbj23:  мозг пациент нейрон животное боль врач нервный рецептор активность нарушение эмоциональный мембрана медицинский синдром чтение
# sbj24:  объект схема познание предмет описание социологический концепт общественный метафора теоретический быт различение парк прикладной теорема
# sbj25:  война россия советский революция страна германия российский партия государственный мировой реформа историк французский франция против
# sbj26:  звезда планета температура земля скорость масса атмосфера солнце нейтронный белый вещество карлик сверхпроводимость образовываться вокруг
# sbj27:  частица энергия квантовый поле физика взаимодействие магнитный электрон кварк теория волна симметрия фотон атом нейтрино
# sbj28:  язык слово русский христианский восток письменность предложение лингвист христианство глагол лингвистика корпус языковой письмо гласный
# bcg:  быть что это который этот как они мочь такой очень для человек или тот один

# %%
for topic_name in model_artm.topic_names:
    print topic_name + ': ',
    tokens = model_artm.score_tracker["top_authors"].last_tokens
    for word in tokens[topic_name]:    
        print word,
    print
# Out:
# sbj0:  Евгений_Шеваль Константин_Северинов Сергей_Киселев Антон_Буздин Петр_Федичев Александр_Жаворонков Ярослав_Ашихмин Андрей_Летаров Светлана_Боринская Евгений_Куликов Александр_Габибов Алексей_Чжао Константин_Мирошников Сергей_Румянцев Владимир_Муронец
# sbj1:  Кирилл_Еськов Валерий_Рубаков Алексей_Старобинский Дмитрий_Горбунов Олег_Верходанов Евгений_Рогожин Макс_Тегмарк Дмитрий_Сорокин Леонард_Полищук Алексей_Северцов Рауль_Гайнетдинов Анатолий_Вишневский Лев_Дудко Шринивас_Шридхар Сергей_Карабасов
# sbj2:  Михаил_Гельфанд Татьяна_Бобровникова Константин_Северинов Андрей_Иванцов Сергей_Науменко Алексей_Кондрашов Юлия_Краус Вера_Ижевская Георгий_Базыкин Михаил_Бурцев Алишер_Тураев Дмитрий_Полдников Мария_Добровольская Алиса_Вячеславова Андрей_Журавлев
# sbj3:  Гасан_Гусейнов Ольга_Артёмова Михаил_Соколов Ивар_Максутов Анна_Соколова Андрей_Кофман Сергей_Пекарский Валентина_Харитонова Игорь_Чубаров Александр_Высоковский Дмитрий_Балалыкин Игорь_Курукин Александр_Каменский Петр_Дружинин Ольга_Вендина
# sbj4:  Мария_Фаликман Константин_Анохин Владимир_Спиридонов Александр_Поддьяков Павел_Умрюхин Наталья_Спасская Виктор_Цетлин Александр_Парфенов Марина_Корсакова-Крейн Дмитрий_Жуков Махзарин_Банаджи Зоя_Зорина Наталья_Кисельникова Олег_Медведев Жанна_Резникова
# sbj5:  Анатолий_Засов Владимир_Сурдин Михаил_Ревнивцев Николай_Дронин Сергей_Троицкий Константин_Лукьянов Василий_Климов Сезар_Идальго Джефф_Лихтман Алексей_Акимов Эмиль_Ахмедов Константин_Воронцов Харольд_Крото Сергей_Ландо Алексей_Моисеев
# sbj6:  Алексей_Козырев Олег_Воскобойников Владимир_Емельянов Александр_Доброхотов Мария_Штейнман Петр_Резвых Иван_Ладынин Аскольд_Иванчик Ольга_Брилева Екатерина_Ларионова Николай_Плотников Сергей_Зенкин Павел_Соколов Оксана_Запорожец Ирина_Стародубровская
# sbj7:  Максим_Франк-Каменецкий Иван_Оселедец Ирина_Бёме Дмитрий_Ветров Илья_Щуров Григорий_Крейдлин Владимир_Каганский Ирина_Левонтина Вера_Подлесская Григорий_Кабатянский Андрей_Головин Андрей_Лосев Марина_Новикова-Грунд Оксана_Запорожец Игорь_Данилевский
# sbj8:  Александр_Марей Павел_Уваров Михаил_Бойцов Алексей_Юдин Кирилл_Мартынов Александр_Филиппов Александр_Павлов Ольга_Малинова Дина_Гусейнова Ольга_Эдельман Леонид_Григорьев Сергей_Серёгичев Сергей_Майоров Олег_Ауров Владимир_Бобровников
# sbj9:  Фёдор_Успенский Сергей_Неклюдов Олег_Лекманов Михаил_Алексеевский Алексей_Лебедев Александра_Архипова Екатерина_Лямина Алина_Бодрова Дмитрий_Добровольский Дмитрий_Бак Владимир_Кантор Григорий_Бондаренко Борис_Иомдин Ян_Левченко Елена_Уханова
# sbj10:  Павел_Руднев Михаил_Соколов Ольга_Вайнштейн Раиса_Кирсанова Алексей_Бартошевич Владимир_Миронов Наталья_Ростиславлева Кирилл_Разлогов Мария_Неклюдова Михаил_Алексеевский Владимир_Кантор Кристофер_Уиншип Сергей_Зенкин Александр_Жданов Алексей_Козырев
# sbj11:  Дмитрий_Дождев Денис_Новак Андрей_Савельев-Трофимов Галина_Зеленина Михаил_Маяцкий Ильдар_Габитов Кит_Моффат Рой_Глаубер Павел_Лушников Константин_Агладзе Алексей_Желтиков Андрей_Наумов Виктор_Веселаго Виктор_Быков Дмитрий_Казанцев
# sbj12:  Виктор_Вахштайн Виталий_Куренной Михаил_Соколов Иван_Болдырев ПостНаука Кирилл_Мартынов Дмитрий_Рогозин Александр_Гофман Александр_Филиппов Наталья_Смолянская Светлана_Баньковская Ирина_Савельева Светлана_Бурлак Алексей_Руткевич Александр_Павлов
# sbj13:  Станислав_Дробышевский Дмитрий_Беляев Варвара_Добровольская Виктория_Битюкова Александр_Лаврентьев Мария_Медникова Галина_Ершова Андрей_Кофман Андрей_Виноградов Сергей_Арутюнов Татьяна_Гусарова Вера_Мильчина Андрей_Журавлев Олег_Ауров Сергей_Серёгичев
# sbj14:  Артем_Оганов Валерий_Фокин Дмитрий_Паращук Валентин_Ненайденко Владимир_Белотелов Владимир_Шалаев Александр_Беленький Валентин_Крапошин Иван_Сорокин Дмитрий_Гольберг Евгений_Гудилин Вадим_Бражкин Пётр_Образцов Рафаэль_Арутюнян Алексей_Хохлов
# sbj15:  Виталий_Кушниров Елена_Браун Эмиль_Ахмедов Андрей_Цатурян Константин_Анохин Михаил_Маяцкий Александр_Войскунский Дмитрий_Дагаев Алексей_Созинов Александр_Никифоров Михаил_Лукин Алексей_Орлов Дэвид_Кларк Дэвид_Кайзер Ольга_Тогоева
# sbj16:  Катерина_Поливанова Наталья_Харламенкова Екатерина_Лапина-Кратасюк Ольга_Исупова Татьяна_Ребеко Сергей_Кулик Екатерина_Протасова Михаил_Киселев Мария_Майофис Елена_Брызгалина Михаил_Маяцкий Татьяна_Котова Наталья_Кисельникова Галина_Зверева Михаил_Полуэктов
# sbj17:  Елизавета_Бонч-Осмоловская Егор_Задереев Марк_Ульянов Алла_Ножевникова Алексей_Маслов Алексей_Малашенко Сергей_Наугольных Андрей_Лукашов Николай_Пименов Зоригто_Намсараев Татьяна_Смоктунович Светлана_Дедыш Дмитрий_Худяков Андрей_Глазовский Игорь_Петров
# sbj18:  Александр_Павлов Варвара_Веденина Антон_Бирюков Андрей_Чабовский Ян_Левченко Сергей_Нечаев Дарья_Радченко Сергей_Деев Евгений_Кац Илья_Кукулин Павел_Нерлер_(Полян) Елизавета_Бонч-Осмоловская Александр_Доброхотов Алексей_Белянин Михаил_Соколов
# sbj19:  Кирилл_Титаев Дмитрий_Дождев Александр_Сафонов Руслан_Смелянский Александр_Тормасов Станислав_Протасов Иван_Луковников Джанмарко_Веруджио Антон_Чижов Станислав_Клименко Мануэль_Маццара Евгений_Магид Евгений_Зуев Эдуард_Пройдаков Александр_Дьяконов
# sbj20:  Елена_Брызгалина Наталья_Зубаревич Татьяна_Клячко Пётр_Турчин Сергей_Бобылев Инга_Полетаева Елена_Гороховская Елена_Вишленкова Сергей_Афонцев Владимир_Гимпельсон Сергей_Гуриев Игорь_Данилевский Виктор_Полтерович Даниэль_Сельва Владимир_Редько
# sbj21:  Алексей_Расторгуев Ольга_Сильченко Анатолий_Засов Игорь_Уточкин Владимир_Комлев Александр_Шацкий Николай_Мощевитин Алексей_Котов Арчил_Балахванцев Алексей_Созинов Эмиль_Ахмедов Владимир_Сурдин Олег_Верходанов Ави_Лёб Светлана_Евграфова
# sbj22:  Фуад_Алескеров Алексей_Белянин Кирилл_Кочегаров Сергей_Соколовский Ольга_Гулевич Василий_Жарков Надежда_Онипенко Мария_Падун Вера_Мильчина Марина_Бутовская Андрей_Зорин Максим_Киселев Ксения_Паниди Григорий_Юдин Василий_Ключарев
# sbj23:  Филипп_Хайтович Павел_Балабан Алексей_Алексеев Дмитрий_Лось Михаил_Пантелеев Александр_Васильев Александр_Каплан Ольга_Сварник Александр_Жданов Юрий_Панчин Дмитрий_Дорохов Александр_Петренко Александр_Лазуткин Максим_Таланов Михаил_Бурцев
# sbj24:  Виктор_Вахштайн Илья_Шкредов Антон_Суворов Александр_Аузан Андрей_Лосев Мария_Майофис Сергей_Гашков Денис_Загарин Василий_Ключарев Дмитрий_Рогозин Татьяна_Котова Жанна_Резникова Виктор_Полтерович Михаил_Соколов Владик_Аветисов
# sbj25:  Илья_Женин Олег_Хлевнюк Дмитрий_Бовыкин Алексей_Миллер Кирилл_Соловьев Борис_Морозов Олег_Будницкий Борис_Колоницкий Дина_Гусейнова Владимир_Малахов Людмила_Новикова Ахмет_Ярлыкапов Алексей_Киличенков Руслан_Хестанов Александр_Воеводский
# sbj26:  Сергей_Попов Дмитрий_Вибе Дмитрий_Титов Владимир_Кузнецов Валерий_Сулейманов Владимир_Пудалов Александр_Слободкин Александр_Потехин Роман_Рафиков Сергей_Блинников Олег_Мельник Наталья_Новикова Александр_Марков Павел_Плечов Армен_Мулкиджанян
# sbj27:  Дмитрий_Казаков Эмиль_Ахмедов Михаил_Данилов Алексей_Рубцов Михаил_Киселев Владимир_Мележик Игорь_Волобуев Сергей_Демокритов Виктор_Брагута Александр_Львовский Наталья_Берлофф Павел_Пахлов Алексей_Семихатов Алексей_Акимов Юджин_Ползик
# sbj28:  Алексей_Муравьёв Владимир_Плунгян Андрей_Кибрик Кирилл_Бабаев Игорь_Исаев Александр_Пиперски Георгий_Старостин Илья_Иткин Анатолий_Баранов Петр_Аркадьев Владимир_Беликов Нина_Сумбатова Алексей_Шмелев Анна_Дыбо Владимир_Петрухин
# bcg:  Борис_Миркин

# %% [markdown]
# В последней теме "bcg" должны находиться общеупотребительные слова.
#
# Важный шаг в работе с тематической моделью, когда речь идет о визуализации или создании тематического навигатора, это именование тем. Понять, о чем каждая тема, можно по списку ее топовых слов. Например, тему
#
#     частица взаимодействие физика кварк симметрия элементарный нейтрино стандартный материя протон бозон заряд масса ускоритель слабый
#
# можно назвать "Физика элементарных частиц".
#
# Дайте названия 29 предметным темам. Если вы не знаете, как назвать тему, назовите ее первым встретившимся в ней существительным, хотя при таком подходе навигатор будет менее информативным. Из названий тем составьте список из 29 строк и запишите го в переменную sbj_topic_labels. В переменной topic_labels будут храниться названия всех тем, включая фоновую.

# %%
sbj_topic_labels = ['Медицинские препараты', 'Земля и космос', 'Генетика', 'Мифология', 
                    'Психология', 'Астрономические измерения', 'Литература и искусство', 
                    'ДНК', 'Гос.устройство в разные времена', 'Письменность Руси', 'Театр', 
                    'Фантастика', 'Философия и культурология', 'Древние народы', 'Перспективные материалы', 
                    'Мыслители Античности', 'Семья', 'Фауна Азиатской акватории', 'Кинотека', 
                    '']   # запишите названия тем в список
topic_labels = sbj_topic_labels + ["Фоновая тема"]

# %% [markdown]
# ##### Анализ тем

# %% [markdown]
# Далее мы будем работать с распределениями тем в документах (матрица $\Theta$) и авторов в темах (одна из двух матриц $\Phi$, соответствующая модальности авторов).
# Создайте переменные, содержащие две этих матрицы, с помощью методов get_phi и get_theta модели. Назовите переменные theta и phi_a. Выведите формы обеих матриц, чтобы понять, по каким осям стоят темы.

# %%
model_artm.theta_columns_naming = "title" # включает именование столбцов Theta их названиями-ссылками, а не внутренними id 
# Ваш код

# %% [markdown]
# Визуализируем фрагмент матрицы $\Theta$ - первые 100 документов (это наиболее простой способ визуально оценить, как темы распределяются в документах). С помощью метода seaborn.heatmap выведите фрагмент theta как изображение. Рекомендация: создайте фигуру pyplot размера (20, 10).

# %%
# Ваш код

# %% [markdown]
# Вы должны увидеть, что фоновая тема имеет большую вероятность в почти каждом документе, и это логично. Кроме того, есть еще одна тема, которая чаще других встречается в документах. Судя по всему, это тема содержит много слов по науку в целом, а каждый документ (видео) в нашей коллекции связан с наукой. Можно (необязательно) дать этой теме название "Наука".
#
# Помимо этих двух тем, фоновой и общенаучной, каждый документ характеризуется малым числом других тем.

# %% [markdown]
# Оценим $p(t)$ - долю каждой темы во всей коллекции. По формуле полной вероятности вычислять эти величины нужно как
# $p(t) = \sum_d p(t|d) p(d)$. Согласно вероятностной модели, $p(d)$ пропорционально длине документа d. Поступим проще: будем полагать, что все документы равновероятны. Тогда оценить $p(t)$ можно, просуммировав $p(t|d)$ по всем документам, а затем разделив полученный вектор на его сумму.
#
# Создайте переменную-датафрейм с T строками, индексированными названиями тем, и 1 столбцом, содержащим оценки $p(t)$. Выведите датафрейм на печать.

# %%
# Ваш код

# %% [markdown]
# Найдите 5 самых распространенных и 3 наименее освещенных темы в коллекции (наибольшие и наименьшие $p(t)$ соответственно), не считая фоновую и общенаучную. Укажите названия, которые вы дали этим темам.

# %% [raw]
# Ваш ответ:
# 5 тем с max p(t):
# 3 темы с min p(t):

# %% [markdown]
# Визуализируйте матрицу $\Phi$ модальности авторов в виде изображения. Рекомендация: установите yticklabels=False в heatmap.

# %%
# Ваш код

# %% [markdown]
# Каждой теме соответствует не очень большое число авторов - матрица достаточно разреженная. Кроме того, некоторые темы имеют доминирующего автора $a$, имеющего большую вероятность $p(a|t)$ - этот автор записал больше всего лекций по теме.

# %% [markdown]
# Будем считать, что автор $a$ значим в теме, если $p(a|t) > 0.01$. Для каждого автора посчитайте, в скольких темах он значим. Найдите авторов-рекордсменов, которые значимы (а значит, читали лекции) в >= 3 темах.

# %% [raw]
# Ваш ответ:
# авторы, значимые в не менее чем 3 темах:

# %% [markdown]
# Большинство авторов значимы в 1 теме, что логично.

# %% [markdown]
# ##### Построение тематической карты авторов

# %% [markdown]
# По сути, в матрице $\Phi$, соответствующей модальности авторов, записаны тематические кластеры авторов. Для любого автора мы можем составить его тематический круг - авторов, разбирающихся в той же теме, что и данный. Интересующиеся слушатели могут попробовать выполнить эту процедуру для ученых, читающих лекции на Постнауке, которых они знают (например, на Постнауке есть лекции с К. В. Воронцовым - лектором текущего модуля :)
#
# Составим карту близости авторов по тематике их исследований. Для этого применим метод понижения размерности MDS к тематическим профилям авторов.
#
# Чтобы получить тематический профиль автора, распределение $p(t|a)$, нужно воспользоваться формулой Байеса:
# $p(t|a) = \frac {p(a|t) p(t)} {\sum_t' p(a|t') p(t')}$. Все необходимые для этого величины у вас есть и записаны в переменных phi и pt.
#
# Передайте матрицу тематических профилей авторов, записанных по строкам, в метод MDS с n_components=2. Используйте косинусную метрику (она хорошо подходит для поиска расстояний между векторами, имеющими фиксированную сумму компонент).

# %%
from sklearn.manifold import MDS
from sklearn.metrics import pairwise_distances

# %%
# Ваш код

# %% [markdown]
# Визуализируйте найденные двумерные представления с помощью функции scatter.

# %%
# Ваш код

# %% [markdown]
# Должно получиться, что некоторые грппы авторов формируют сгустки, которые можно считать тематическими группами авторов.
#
# Раскрасим точки следующим образом: для каждого автора выберем наиболее вероятную для него тему ($\max_t p(t|a)$), и каждой теме сопоставим цвет. Кроме того, добавим на карту имена и фамилии авторов, это можно сделать в цикле по всем точкам с помощью функции plt.annotate, указывая метку точки первым аргументом и ее координаты в аргументе xy. Рекомендуется сделать размер изображения большим, тогда маркеры точек тоже придется увеличить (s=100 в plt.scatter). Изобразите карту авторов и сохраните в pdf-файл с помощью функции plt.savefig.
#
# Метки авторов будут пересекаться. Будет очень хорошо, если вы найдете способ, как этого можно избежать.

# %%
import matplotlib.cm as cm
colors = cm.rainbow(np.linspace(0, 1, T)) # цвета для тем
# Ваш код

# %% [markdown]
# ##### Создание простого тематического навигатора по Постнауке

# %% [markdown]
# Наш тематический навигатор будет для каждой темы показывать ее список слов, а также список релевантных теме документов.
#
# Нам понадобятся распределения $p(d|t)$. По формуле Байеса $p(d|t) = \frac{p(t|d)p(d)}{\sum_{d'}p(t|d')p(d')}$, но поскольку мы считаем документы равновероятными, достаточно разделить каждую строку $\Theta$ на ее сумму, чтобы оценить распределение.
#
# Отсортируйте матрицу $p(d|t)$ по убыванию $p(d|t)$ в каждой теме (то есть построчно). Нам понадобятся индексы наиболее вероятных документов в каждой теме, поэтому используйте функцию argmax.

# %%
# Ваш код

# %% [markdown]
# Создавать навигатор мы будем прямо в jupiter notebook: это возможно благодаря тому факту, что при печати ссылки она автоматически превращается в гиперссылку.

# %%
print "http://yandex.ru"   # получится кликабельная ссылка

# %% [markdown]
# Кроме того, подключив модуль [ipython.core.display](https://ipython.org/ipython-doc/2/api/generated/IPython.core.display.html), можно использовать html-разметку в выводе. Например:

# %%
from IPython.core.display import display, HTML
display(HTML(u"<h1>Заголовок</h1>"))   # также <h2>, <h3>
display(HTML(u"<ul><li>Пункт 1</li><li>Пункт 2</li></ul>"))
display(HTML(u'<font color="green">Зеленый!</font>'))
display(HTML(u'<a href="http://yandex.ru">Еще один вариант вывода ссылки</a>'))
# Out:
# <h1>Заголовок</h1>
# <ul><li>Пункт 1</li><li>Пункт 2</li></ul>
# <font color="green">Зеленый!</font>
# <a href="http://yandex.ru">Еще один вариант вывода ссылки</a>

# %% [markdown]
# В цикле для каждой темы выведите ее заголовок, в следующей строке - топ-10 слов темы, затем в виде списка ссылки на 10 наиболее релевантных (по $p(d|t)$) теме документов. Используйте html-разметку. Творчество приветствуется :)

# %%
# Ваш код

# %% [markdown]
# ##### Заключение

# %% [markdown]
# В этом Peer Review мы познакомились с базовыми возможностями библиотеки BigARTM и с методами визуализации тематических моделей. Визуализация тематических моделей - это широкая и активно развивающаяся область научных исследований. Мы рассмотрели только самые простые приемы. Желающие могут попробовать применить [Serendip](http://vep.cs.wisc.edu/serendip/#serendipHero), разработанный в  University of Wisconsin-Madison, к построенной модели. Эта библиотека позволяет максимально полно охарактеризовать темы и написана для языка python.
#
# Сделав задание, вы можете выбрать в навигаторе наиболее интересную для вас тему и посмотреть видеолекции :) На Постнауке очень много интересных материалов.
